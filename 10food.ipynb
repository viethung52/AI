# %% [markdown]
# <a href="https://colab.research.google.com/github/viethung52/AI/blob/main/10food.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
folder= '/content/drive/MyDrive/AI/food/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'banhcuon'+ str(100+i) +'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()
folder = '/content/drive/MyDrive/AI/food/'

photos, labels = list(), list()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for file in listdir(folder):
  if file.startswith('banhcuon'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhkhot'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhmi'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banhxeo'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('bolalot'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('bunbo'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('chagio'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('comtam'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('mucrim'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('phoga'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

# %%
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)
save('10foods_photos.npy', photos)
save('10foods_labels.npy', labels)
# Out:
# (700, 200, 200, 3) (700,)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(16, activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels, batch_size=64,epochs=50, verbose=1)
model.save('10foods.h5')
# Out:
# Epoch 1/50
# 11/11 [==============================] - 2s 89ms/step - loss: 5.9669 - accuracy: 0.5071
# Epoch 2/50
# 11/11 [==============================] - 1s 86ms/step - loss: 1.4806 - accuracy: 0.5429
# Epoch 3/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.6623 - accuracy: 0.7914
# Epoch 4/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.3015 - accuracy: 0.9057
# Epoch 5/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0947 - accuracy: 0.9757
# Epoch 6/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0699 - accuracy: 0.9829
# Epoch 7/50
# 11/11 [==============================] - 1s 86ms/step - loss: 0.0223 - accuracy: 0.9957
# Epoch 8/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0242 - accuracy: 0.9929
# Epoch 9/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0595 - accuracy: 0.9886
# Epoch 10/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0620 - accuracy: 0.9814
# Epoch 11/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0913 - accuracy: 0.9757
# Epoch 12/50
# 11/11 [==============================] - 1s 86ms/step - loss: 0.0382 - accuracy: 0.9914
# Epoch 13/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0093 - accuracy: 0.9971
# Epoch 14/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0197 - accuracy: 0.9914
# Epoch 15/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0301 - accuracy: 0.9929
# Epoch 16/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0619 - accuracy: 0.9814
# Epoch 17/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0829 - accuracy: 0.9729
# Epoch 18/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.1137 - accuracy: 0.9657
# Epoch 19/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.1133 - accuracy: 0.9743
# Epoch 20/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.1154 - accuracy: 0.9757
# Epoch 21/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.2002 - accuracy: 0.9686
# Epoch 22/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0862 - accuracy: 0.9757
# Epoch 23/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.1248 - accuracy: 0.9814
# Epoch 24/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0532 - accuracy: 0.9857
# Epoch 25/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0899 - accuracy: 0.9757
# Epoch 26/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0421 - accuracy: 0.9886
# Epoch 27/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0342 - accuracy: 0.9886
# Epoch 28/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.2055 - accuracy: 0.9843
# Epoch 29/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.1364 - accuracy: 0.9714
# Epoch 30/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.1690 - accuracy: 0.9700
# Epoch 31/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0263 - accuracy: 0.9900
# Epoch 32/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.9185 - accuracy: 0.8371
# Epoch 33/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.7844 - accuracy: 0.8700
# Epoch 34/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.3084 - accuracy: 0.9471
# Epoch 35/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.1296 - accuracy: 0.9771
# Epoch 36/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.1181 - accuracy: 0.9771
# Epoch 37/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0743 - accuracy: 0.9814
# Epoch 38/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0552 - accuracy: 0.9814
# Epoch 39/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0107 - accuracy: 0.9971
# Epoch 40/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0101 - accuracy: 0.9971
# Epoch 41/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 42/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0059 - accuracy: 0.9986
# Epoch 43/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0141 - accuracy: 0.9943
# Epoch 44/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0128 - accuracy: 0.9971
# Epoch 45/50
# 11/11 [==============================] - 1s 89ms/step - loss: 0.0179 - accuracy: 0.9957
# Epoch 46/50
# 11/11 [==============================] - 1s 88ms/step - loss: 0.0287 - accuracy: 0.9929
# Epoch 47/50
# 11/11 [==============================] - 1s 87ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 48/50
# 11/11 [==============================] - 1s 88ms/step - loss: 4.9993e-04 - accuracy: 1.0000
# Epoch 49/50
# 11/11 [==============================] - 1s 90ms/step - loss: 1.6995e-04 - accuracy: 1.0000
# Epoch 50/50
# 11/11 [==============================] - 1s 88ms/step - loss: 1.1085e-04 - accuracy: 1.0000

# %%
classes = ["banhcuon","banhkhot","banhmi","banhxeo","bolalot","bunbo","chagio","comtam","mucrim","phoga"]
img = load_img('/content/drive/MyDrive/AI/food/banhcuon100.jpg', target_size=(200,200))
plt.imshow(img)

# %%
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.08235373 0.06232648 0.07043754 0.0701833  0.05748631 0.07407934
#   0.07348721 0.06859203 0.06348188 0.07465404 0.05247124 0.04730904
#   0.0487525  0.05074725 0.05187638 0.0517617 ]]
# 'banhcuon'

# %%
classes = ["banhcuon","banhkhot","banhmi","banhxeo","bolalot","bunbo","chagio","comtam","mucrim","phoga"]
img = load_img('/content/drive/MyDrive/AI/food/comtam150.jpg', target_size=(200,200))
plt.imshow(img)
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.07193515 0.06786013 0.06408628 0.07095919 0.06274801 0.07993808
#   0.07249412 0.10432845 0.06662549 0.06815086 0.04687325 0.03862904
#   0.04374689 0.04510792 0.05023757 0.04627956]]
# 'comtam'
