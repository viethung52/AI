# %% [markdown]
# <a href="https://colab.research.google.com/github/viethung52/AI/blob/main/tiengiay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.optimizers  import SGD
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder= '/content/drive/MyDrive/AI/tiengiay/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'dollar'+ str(i) +'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()
folder = '/content/drive/MyDrive/AI/tiengiay/'

photos, labels = list(), list()

# %%
for file in listdir(folder):
  if file.startswith('dollar'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('haimuoingan'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('haingan'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('haitramngan'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('malaysia'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('motngan'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('mottramngan'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('muoingan'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('nammuoingan'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('namngan'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

# %%
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('Fruits_photos.npy', photos)
save('Fruits_labels.npy', labels)
# Out:
# (250, 200, 200, 3) (250,)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(16, activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels, batch_size=64,epochs=20, verbose=1)
model.save('tiengiay.h5')
# Out:
# Epoch 1/20
# 4/4 [==============================] - 14s 411ms/step - loss: 394.9895 - accuracy: 0.0520
# Epoch 2/20
# 4/4 [==============================] - 0s 88ms/step - loss: 42.8942 - accuracy: 0.0880
# Epoch 3/20
# 4/4 [==============================] - 0s 88ms/step - loss: 3.2138 - accuracy: 0.1680
# Epoch 4/20
# 4/4 [==============================] - 0s 88ms/step - loss: 1.6470 - accuracy: 0.4800
# Epoch 5/20
# 4/4 [==============================] - 0s 87ms/step - loss: 0.9593 - accuracy: 0.7280
# Epoch 6/20
# 4/4 [==============================] - 0s 88ms/step - loss: 0.3911 - accuracy: 0.8840
# Epoch 7/20
# 4/4 [==============================] - 0s 88ms/step - loss: 0.1838 - accuracy: 0.9520
# Epoch 8/20
# 4/4 [==============================] - 0s 86ms/step - loss: 0.0767 - accuracy: 0.9800
# Epoch 9/20
# 4/4 [==============================] - 0s 88ms/step - loss: 0.0432 - accuracy: 0.9920
# Epoch 10/20
# ...

# %%
classes = ["dollar","haimuoingan","haingan","haitramngan","malaysia","motngan","mottramngan","muoingan","nammuoingan","namngan"]
img = load_img('/content/drive/MyDrive/AI/tiengiay/motngan21.jpg', target_size=(200,200))
plt.imshow(img)

# %%
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.06184007 0.06582443 0.06516602 0.06176024 0.06533964 0.06824774
#   0.0644479  0.06410219 0.06579313 0.06443148 0.05778222 0.05901477
#   0.05846268 0.05773909 0.05915444 0.06089392]]
# 'motngan'

# %%
classes = ["dollar","haimuoingan","haingan","haitramngan","malaysia","motngan","mottramngan","muoingan","nammuoingan","namngan"]
img = load_img('/content/drive/MyDrive/AI/tiengiay/dollar21.jpg', target_size=(200,200))
plt.imshow(img)

# %%
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.07101687 0.06615457 0.06519932 0.06245834 0.06283204 0.06199675
#   0.06738667 0.06508277 0.0669555  0.06531182 0.05707049 0.05840778
#   0.05188966 0.05697655 0.06264716 0.0586137 ]]
# 'dollar'
